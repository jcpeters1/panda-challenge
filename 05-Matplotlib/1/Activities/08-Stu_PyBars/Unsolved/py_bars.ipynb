# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis, bars_in_cities, color='blue', align='center')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
tick_loc = [value for value in x_axis]
plt.xticks(tick_loc, cities)
# Out:
# ([<matplotlib.axis.XTick at 0x113fb89d0>,
#   <matplotlib.axis.XTick at 0x113fcaa90>,
#   <matplotlib.axis.XTick at 0x1149867d0>,
#   <matplotlib.axis.XTick at 0x1149b5910>,
#   <matplotlib.axis.XTick at 0x1149b5950>],
#  <a list of 5 Text xticklabel objects>)

# %%
# Set the limits of the x axis
plt.xlim(-.75, len(x_axis)-.25)
# Out:
# (-0.75, 4.75)

# %%
# Set the limits of the y axis
plt.ylim(0,9)
# Out:
# (0, 9)

# %%
# Give the chart a title, x label, and y label
plt.title('Density of Bars in Cities')
plt.ylabel('Bars Per 10,000 Households')
plt.xlabel('Cities')
# Out:
# Text(0.5, 47.04444444444444, 'Cities')

# %%
# Save an image of the chart and print it to the screen
plt.savefig('../Images/py_bars.png')
